# %% [markdown]
# # Pandas 심화 (2020-2학기 인사이트 교육세션)
#
# - groupby
# - merge
# - pivot_table
# - stack, unstack

# %%
import pandas as pd

# %%
# csv 파일 불러오기
data_path = 'data/'

seoulfloating = pd.read_csv(data_path + 'SeoulFloating.csv')
patientInfo = pd.read_csv(data_path + 'PatientInfo.csv')
seoulfloating.head()
# Out:
#          date  hour  birth_year     sex province           city  fp_num
# 0  2020-01-01     0          20  female    Seoul      Dobong-gu   19140
# 1  2020-01-01     0          20    male    Seoul      Dobong-gu   19950
# 2  2020-01-01     0          20  female    Seoul  Dongdaemun-gu   25450
# 3  2020-01-01     0          20    male    Seoul  Dongdaemun-gu   27050
# 4  2020-01-01     0          20  female    Seoul     Dongjag-gu   28880

# %% [markdown]
# ## groupby
#
# - 명목변수를 기준으로 그룹별로 데이터를 묶어주는 함수
#
#
# 1. agg
# 2. lambda
# 3. apply

# %% [markdown]
# ### DataFrame.groupby('컬럼명') 으로 사용
# - groupby 객체를 리턴해주기 때문에 원하는 값을 조회하려면 추가적인 함수를 사용해야함
# - 여러개의 컬럼을 기준으로 그룹핑하려면
# - DataFrame.groupby(['컬럼명1','컬럼명2']) 로 사용해주면 됨
#
#
#
# - DataFrame.groupby('컬럼명').함수() 처럼 사용하면
#     - 컬럼별로 데이터를 묶어주고 함수를 적용시켜줌

# %%
# groupby 함수로 날짜별 합계
# groupby 객체를 리턴해줌

seoulfloating.groupby('date')

# %%
# 원하는 데이터를 조회하기 위해서 추가적인 함수를 사용해야함
# 날짜별로 합계를 조회함

seoulfloating.groupby('date').sum()
# Out:
#              hour  birth_year     fp_num
# date
# 2020-01-01  82800      324000  192406170
# 2020-01-02  82800      324000  202929360
# 2020-01-03  82800      324000  203337150
# 2020-01-04  82800      324000  197396050
# 2020-01-05  82800      324000  195747670
# ...           ...         ...        ...
# 2020-05-27  82800      324000  199293080
# 2020-05-28  82800      324000  199209840
# 2020-05-29  40800      229500  140847320
# 2020-05-30  82800      324000  189674150
# 2020-05-31  82800      324000  188346500
#
# [151 rows x 3 columns]

# %% [markdown]
# ### agg
#
# - 각종 통계량을 보는 함수
# - DataFrame.groupby('컬럼').agg([함수1, 함수2, ...])
#
#
# - 기본적으로 간단한 통계함수(평균, 합, 최댓값, 최솟값, 표준편차)는 지원해줌

# %%
# 합계, 평균, 최댓값, 최솟값, 표준편차

seoulfloating.groupby('date').agg(['mean', 'sum', 'max', 'min', 'std'])['fp_num']
# Out:
#                     mean        sum     max   min           std
# date
# 2020-01-01  26723.079167  192406170   58790  5000  10141.901583
# 2020-01-02  28184.633333  202929360  121050  4970  13123.840968
# 2020-01-03  28241.270833  203337150  122400  5190  13203.603225
# 2020-01-04  27416.118056  197396050   79880  5200  10884.040223
# 2020-01-05  27187.176389  195747670   65310  5040  10517.133129
# ...                  ...        ...     ...   ...           ...
# 2020-05-27  27679.594444  199293080  120120  4670  13360.498096
# 2020-05-28  27668.033333  199209840  119810  4650  13358.392621
# 2020-05-29  27617.121569  140847320  117730  4670  13565.792431
# 2020-05-30  26343.631944  189674150   74900  4560  11076.653088
# 2020-05-31  26159.236111  188346500   60890  4410  10825.771618
#
# [151 rows x 5 columns]

# %%
# 사용자 정의 함수 가능

def my_mean(x):
    return sum(x) / len(x)

# list로 안받아주면 Series로 출력
seoul_mean = seoulfloating.groupby('city')['fp_num'].agg([my_mean])
seoul_mean
# Out:
#                       my_mean
# city
# Dobong-gu        20048.519082
# Dongdaemun-gu    24221.652148
# Dongjag-gu       26070.771110
# Eunpyeong-gu     28041.551899
# Gangbuk-gu       19911.660444
# Gangdong-gu      27832.631361
# Gangnam-gu       48831.048811
# Gangseo-gu       36899.837528
# Geumcheon-gu     18908.174087
# Guro-gu          29579.639795
# Gwanak-gu        32990.330706
# Gwangjin-gu      23829.569045
# Jongno-gu        17906.022308
# Jung-gu          18241.025304
# Jungnang-gu      24649.747649
# Mapo-gu          28341.201143
# Nowon-gu         33197.496774
# Seocho-gu        34212.159154
# Seodaemun-gu     21205.910306
# Seongbuk-gu      28185.835177
# Seongdong-gu     21345.661182
# Songpa-gu        43351.922474
# Yangcheon-gu     27386.343105
# Yeongdeungpo-gu  32800.775719
# Yongsan-gu       17684.644635

# %% [markdown]
# ## 실습1. SeoulFloating 데이터에서 유동인구를 연령별로 조회

# %%
# 아래와 같은 결과가 나오면 됩니다!!
a = seoulfloating.groupby('birth_year').agg('sum')
pd.DataFrame(a['fp_num'])
# Out:
#                 fp_num
# birth_year
# 20          5441769700
# 30          6069018790
# 40          6054699830
# 50          5675739830
# 60          3706127050
# 70          2805416690

# %% [markdown]
# ### lambda
#
# - 함수를 간단히 한줄로 표현가능
# - lambda 변수1, 변수2, ... : 변수들의 연산

# %%
# lambda 예시 : 두 수의 곱셈을 구현

f = lambda x, y : x*y
f(2,5)
# Out:
# 10

# %%
# lambda를 이용한 유동인구 평균 구하기

seoulfloating.groupby('city').agg([lambda x: (sum(x) / len(x))])['fp_num']
# Out:
#                      <lambda>
# city
# Dobong-gu        20048.519082
# Dongdaemun-gu    24221.652148
# Dongjag-gu       26070.771110
# Eunpyeong-gu     28041.551899
# Gangbuk-gu       19911.660444
# Gangdong-gu      27832.631361
# Gangnam-gu       48831.048811
# Gangseo-gu       36899.837528
# Geumcheon-gu     18908.174087
# Guro-gu          29579.639795
# Gwanak-gu        32990.330706
# Gwangjin-gu      23829.569045
# Jongno-gu        17906.022308
# Jung-gu          18241.025304
# Jungnang-gu      24649.747649
# Mapo-gu          28341.201143
# Nowon-gu         33197.496774
# Seocho-gu        34212.159154
# Seodaemun-gu     21205.910306
# Seongbuk-gu      28185.835177
# Seongdong-gu     21345.661182
# Songpa-gu        43351.922474
# Yangcheon-gu     27386.343105
# Yeongdeungpo-gu  32800.775719
# Yongsan-gu       17684.644635

# %% [markdown]
# ### apply
#
# - agg는 여러함수를 한번에 처리가능, groupby 객체에 최적화
# - 통계량을 다루기 때문에 데이터type중 숫자형만 가능
# - apply는 dataframe형식에 최적화
#
#
# - DataFrame.apply(함수, axis) 으로 사용
# - axis는 데이터의 처리방향 결정 0은 행방향, 1은 열방향 보통 1을 많이 씀

# %%
seoul_mean
# Out:
#                       my_mean
# city
# Dobong-gu        20048.519082
# Dongdaemun-gu    24221.652148
# Dongjag-gu       26070.771110
# Eunpyeong-gu     28041.551899
# Gangbuk-gu       19911.660444
# Gangdong-gu      27832.631361
# Gangnam-gu       48831.048811
# Gangseo-gu       36899.837528
# Geumcheon-gu     18908.174087
# Guro-gu          29579.639795
# Gwanak-gu        32990.330706
# Gwangjin-gu      23829.569045
# Jongno-gu        17906.022308
# Jung-gu          18241.025304
# Jungnang-gu      24649.747649
# Mapo-gu          28341.201143
# Nowon-gu         33197.496774
# Seocho-gu        34212.159154
# Seodaemun-gu     21205.910306
# Seongbuk-gu      28185.835177
# Seongdong-gu     21345.661182
# Songpa-gu        43351.922474
# Yangcheon-gu     27386.343105
# Yeongdeungpo-gu  32800.775719
# Yongsan-gu       17684.644635

# %%
# lambda를 이용해 3개의 조건을 이용한 함수를 만듦
# axis = 1로 설정해 열방향으로 처리

seoul_mean.apply(lambda x : '상' if x['my_mean'] > 40000
                else '중' if x['my_mean'] > 20000
                else '하', axis = 1).to_frame()
# Out:
#                  0
# city
# Dobong-gu        중
# Dongdaemun-gu    중
# Dongjag-gu       중
# Eunpyeong-gu     중
# Gangbuk-gu       하
# Gangdong-gu      중
# Gangnam-gu       상
# Gangseo-gu       중
# Geumcheon-gu     하
# Guro-gu          중
# Gwanak-gu        중
# Gwangjin-gu      중
# Jongno-gu        하
# Jung-gu          하
# Jungnang-gu      중
# Mapo-gu          중
# Nowon-gu         중
# Seocho-gu        중
# Seodaemun-gu     중
# Seongbuk-gu      중
# Seongdong-gu     중
# Songpa-gu        상
# Yangcheon-gu     중
# Yeongdeungpo-gu  중
# Yongsan-gu       하

# %%
# series 데이터 타입에 apply를 적용하는 법

seoul_mean['순위'] = seoul_mean['my_mean'].apply(lambda x : '상' if x > 40000
                else '중' if x>20000
                else '하')
seoul_mean
# Out:
#                       my_mean 순위
# city
# Dobong-gu        20048.519082  중
# Dongdaemun-gu    24221.652148  중
# Dongjag-gu       26070.771110  중
# Eunpyeong-gu     28041.551899  중
# Gangbuk-gu       19911.660444  하
# Gangdong-gu      27832.631361  중
# Gangnam-gu       48831.048811  상
# Gangseo-gu       36899.837528  중
# Geumcheon-gu     18908.174087  하
# Guro-gu          29579.639795  중
# Gwanak-gu        32990.330706  중
# Gwangjin-gu      23829.569045  중
# Jongno-gu        17906.022308  하
# Jung-gu          18241.025304  하
# Jungnang-gu      24649.747649  중
# Mapo-gu          28341.201143  중
# Nowon-gu         33197.496774  중
# Seocho-gu        34212.159154  중
# Seodaemun-gu     21205.910306  중
# Seongbuk-gu      28185.835177  중
# Seongdong-gu     21345.661182  중
# Songpa-gu        43351.922474  상
# Yangcheon-gu     27386.343105  중
# Yeongdeungpo-gu  32800.775719  중
# Yongsan-gu       17684.644635  하

# %%
# 위 함수는 다음과 같음
# apply 역시 함수를 정의해서 사용가능

def rank(x):
    if x > 40000:
        return '상'
    elif x > 20000:
        return '중'
    else:
        return '하'
    
seoul_mean['my_mean'].apply([rank])
# Out:
#                 rank
# city
# Dobong-gu          중
# Dongdaemun-gu      중
# Dongjag-gu         중
# Eunpyeong-gu       중
# Gangbuk-gu         하
# Gangdong-gu        중
# Gangnam-gu         상
# Gangseo-gu         중
# Geumcheon-gu       하
# Guro-gu            중
# Gwanak-gu          중
# Gwangjin-gu        중
# Jongno-gu          하
# Jung-gu            하
# Jungnang-gu        중
# Mapo-gu            중
# Nowon-gu           중
# Seocho-gu          중
# Seodaemun-gu       중
# Seongbuk-gu        중
# Seongdong-gu       중
# Songpa-gu          상
# Yangcheon-gu       중
# Yeongdeungpo-gu    중
# Yongsan-gu         하

# %% [markdown]
# ## 실습2. SeoulFloating 데이터에서 마포구의 유동인구를 날짜와 연령별로 조회

# %%
# 아래와 같은 결과가 나오면 됩니다!!
a = seoulfloating.copy()
a = a[a['city'] == 'Mapo-gu']
pd.DataFrame(a.groupby(['date','birth_year']).sum()['fp_num'])
# Out:
#                         fp_num
# date       birth_year
# 2020-01-01 20          1660930
#            30          1637350
#            40          1492290
#            50          1267310
#            60           854060
# ...                        ...
# 2020-05-31 30          1740330
#            40          1500480
#            50          1247850
#            60           777610
#            70           698970
#
# [906 rows x 1 columns]

# %% [markdown]
# ## merge
#
# - 두개의 테이블을 같은 컬럼을 기준으로 병합
#
#
# - pd.merge(데이터프레임1, 데이터프레임2, on = '컬럼명', how = '')
#     - how에 들어갈 인자는 inner, outer, left, right 등등이 있다
#     - default 값은 inner

# %%
# 각종 지역정보를 담고있는 데이터

region = pd.read_csv(data_path + 'Region.csv')
region.head()
# Out:
#     code province         city   latitude   longitude  \
# 0  10000    Seoul        Seoul  37.566953  126.977977
# 1  10010    Seoul   Gangnam-gu  37.518421  127.047222
# 2  10020    Seoul  Gangdong-gu  37.530492  127.123837
# 3  10030    Seoul   Gangbuk-gu  37.639938  127.025508
# 4  10040    Seoul   Gangseo-gu  37.551166  126.849506
#
#    elementary_school_count  kindergarten_count  university_count  \
# 0                      607                 830                48
# 1                       33                  38                 0
# 2                       27                  32                 0
# 3                       14                  21                 0
# 4                       36                  56                 1
#
#    academy_ratio  elderly_population_ratio  elderly_alone_ratio  \
# 0           1.44                     15.38                  5.8
# 1           4.18                     13.17                  4.3
# 2           1.54                     14.55                  5.4
# 3           0.67                     19.49                  8.5
# 4           1.17                     14.39                  5.7
#
#    nursing_home_count
# 0               22739
# 1                3088
# 2                1023
# 3                 628
# 4                1080

# %%
# 환자정보 데이터

patientInfo.head()
# Out:
#    patient_id     sex  age country province         city  \
# 0  1000000001    male  50s   Korea    Seoul   Gangseo-gu
# 1  1000000002    male  30s   Korea    Seoul  Jungnang-gu
# 2  1000000003    male  50s   Korea    Seoul    Jongno-gu
# 3  1000000004    male  20s   Korea    Seoul      Mapo-gu
# 4  1000000005  female  20s   Korea    Seoul  Seongbuk-gu
#
#          infection_case infected_by contact_number symptom_onset_date  \
# 0       overseas inflow         NaN             75         2020-01-22
# 1       overseas inflow         NaN             31                NaN
# 2  contact with patient  2002000001             17                NaN
# 3       overseas inflow         NaN              9         2020-01-26
# 4  contact with patient  1000000002              2                NaN
#
#   confirmed_date released_date deceased_date     state
# 0     2020-01-23    2020-02-05           NaN  released
# 1     2020-01-30    2020-03-02           NaN  released
# 2     2020-01-30    2020-02-19           NaN  released
# 3     2020-01-30    2020-02-15           NaN  released
# 4     2020-01-31    2020-02-24           NaN  released

# %%
# 환자정보중 서울거주자만 조회

seoul_patientInfo = patientInfo[patientInfo['province'] == 'Seoul']
seoul_patientInfo.head()
# Out:
#    patient_id     sex  age country province         city  \
# 0  1000000001    male  50s   Korea    Seoul   Gangseo-gu
# 1  1000000002    male  30s   Korea    Seoul  Jungnang-gu
# 2  1000000003    male  50s   Korea    Seoul    Jongno-gu
# 3  1000000004    male  20s   Korea    Seoul      Mapo-gu
# 4  1000000005  female  20s   Korea    Seoul  Seongbuk-gu
#
#          infection_case infected_by contact_number symptom_onset_date  \
# 0       overseas inflow         NaN             75         2020-01-22
# 1       overseas inflow         NaN             31                NaN
# 2  contact with patient  2002000001             17                NaN
# 3       overseas inflow         NaN              9         2020-01-26
# 4  contact with patient  1000000002              2                NaN
#
#   confirmed_date released_date deceased_date     state
# 0     2020-01-23    2020-02-05           NaN  released
# 1     2020-01-30    2020-03-02           NaN  released
# 2     2020-01-30    2020-02-19           NaN  released
# 3     2020-01-30    2020-02-15           NaN  released
# 4     2020-01-31    2020-02-24           NaN  released

# %%
# city를 기준으로 확진자 수 계산

seoul_patients = seoul_patientInfo.groupby('city').count()[['patient_id']].reset_index()
seoul_patients
# Out:
#                city  patient_id
# 0         Dobong-gu          62
# 1     Dongdaemun-gu          38
# 2        Dongjak-gu          53
# 3      Eunpyeong-gu          53
# 4        Gangbuk-gu          24
# 5       Gangdong-gu          35
# 6        Gangnam-gu          83
# 7        Gangseo-gu          78
# 8      Geumcheon-gu          32
# 9           Guro-gu          85
# 10        Gwanak-gu         113
# 11      Gwangjin-gu          17
# 12        Jongno-gu          22
# 13          Jung-gu          12
# 14      Jungnang-gu          33
# 15          Mapo-gu          38
# 16         Nowon-gu          43
# 17        Seocho-gu          55
# 18     Seodaemun-gu          36
# 19      Seongbuk-gu          33
# 20     Seongdong-gu          49
# 21        Songpa-gu          55
# 22     Yangcheon-gu          71
# 23  Yeongdeungpo-gu          62
# 24       Yongsan-gu          50
# 25              etc          80

# %%
# 서울지역의 데이터 조회 

region_seoul = region[region['province'] == 'Seoul']
region_seoul
# Out:
#      code province             city   latitude   longitude  \
# 0   10000    Seoul            Seoul  37.566953  126.977977
# 1   10010    Seoul       Gangnam-gu  37.518421  127.047222
# 2   10020    Seoul      Gangdong-gu  37.530492  127.123837
# 3   10030    Seoul       Gangbuk-gu  37.639938  127.025508
# 4   10040    Seoul       Gangseo-gu  37.551166  126.849506
# 5   10050    Seoul        Gwanak-gu  37.478290  126.951502
# 6   10060    Seoul      Gwangjin-gu  37.538712  127.082366
# 7   10070    Seoul          Guro-gu  37.495632  126.887650
# 8   10080    Seoul     Geumcheon-gu  37.456852  126.895229
# 9   10090    Seoul         Nowon-gu  37.654259  127.056294
# 10  10100    Seoul        Dobong-gu  37.668952  127.047082
# 11  10110    Seoul    Dongdaemun-gu  37.574552  127.039721
# 12  10120    Seoul       Dongjak-gu  37.510571  126.963604
# 13  10130    Seoul          Mapo-gu  37.566283  126.901644
# 14  10140    Seoul     Seodaemun-gu  37.579428  126.936771
# 15  10150    Seoul        Seocho-gu  37.483804  127.032693
# 16  10160    Seoul     Seongdong-gu  37.563277  127.036647
# 17  10170    Seoul      Seongbuk-gu  37.589562  127.016700
# 18  10180    Seoul        Songpa-gu  37.514620  127.106141
# 19  10190    Seoul     Yangcheon-gu  37.517189  126.866618
# 20  10200    Seoul  Yeongdeungpo-gu  37.526505  126.896190
# 21  10210    Seoul       Yongsan-gu  37.532768  126.990021
# 22  10220    Seoul     Eunpyeong-gu  37.603481  126.929173
# 23  10230    Seoul        Jongno-gu  37.572999  126.979189
# 24  10240    Seoul          Jung-gu  37.563988  126.997530
# 25  10250    Seoul      Jungnang-gu  37.606832  127.092656
#
#     elementary_school_count  kindergarten_count  university_count  \
# 0                       607                 830                48
# 1                        33                  38                 0
# 2                        27                  32                 0
# 3                        14                  21                 0
# 4                        36                  56                 1
# 5                        22                  33                 1
# 6                        22                  33                 3
# 7                        26                  34                 3
# 8                        18                  19                 0
# 9                        42                  66                 6
# 10                       23                  26                 1
# 11                       21                  31                 4
# 12                       21                  34                 3
# 13                       22                  24                 2
# 14                       19                  25                 6
# 15                       24                  27                 1
# 16                       21                  30                 2
# 17                       29                  49                 6
# 18                       40                  51                 1
# 19                       30                  43                 0
# 20                       23                  39                 0
# 21                       15                  13                 1
# 22                       31                  44                 1
# 23                       13                  17                 3
# 24                       12                  14                 2
# 25                       23                  31                 1
#
#     academy_ratio  elderly_population_ratio  elderly_alone_ratio  \
# 0            1.44                     15.38                  5.8
# 1            4.18                     13.17                  4.3
# 2            1.54                     14.55                  5.4
# 3            0.67                     19.49                  8.5
# 4            1.17                     14.39                  5.7
# 5            0.89                     15.12                  4.9
# 6            1.16                     13.75                  4.8
# 7            1.00                     16.21                  5.7
# 8            0.96                     16.15                  6.7
# 9            1.39                     15.40                  7.4
# 10           0.95                     17.89                  7.2
# 11           1.06                     17.26                  6.7
# 12           1.17                     15.85                  5.2
# 13           1.83                     14.05                  4.9
# 14           1.12                     16.77                  6.2
# 15           2.60                     13.39                  3.8
# 16           0.97                     14.76                  5.3
# 17           1.02                     16.15                  6.0
# 18           1.65                     13.10                  4.1
# 19           2.26                     13.55                  5.5
# 20           1.21                     15.60                  5.8
# 21           0.68                     16.87                  6.5
# 22           1.09                     17.00                  6.5
# 23           1.71                     18.27                  6.8
# 24           0.94                     18.42                  7.4
# 25           0.70                     16.65                  6.9
#
#     nursing_home_count
# 0                22739
# 1                 3088
# 2                 1023
# 3                  628
# 4                 1080
# 5                  909
# 6                  723
# 7                  741
# 8                  475
# 9                  952
# 10                 485
# 11                 832
# 12                 762
# 13                 929
# 14                 587
# 15                1465
# 16                 593
# 17                 729
# 18                1527
# 19                 816
# 20                1001
# 21                 435
# 22                 874
# 23                 668
# 24                 728
# 25                 689

# %%
# 교집합을 조회하는 inner join

pd.merge(region_seoul, seoul_patients, on='city')
# pd.merge(region_seoul, seoul_patients, on='city', how = 'inner') 과 결과가 같음
# Out:
#      code province             city   latitude   longitude  \
# 0   10010    Seoul       Gangnam-gu  37.518421  127.047222
# 1   10020    Seoul      Gangdong-gu  37.530492  127.123837
# 2   10030    Seoul       Gangbuk-gu  37.639938  127.025508
# 3   10040    Seoul       Gangseo-gu  37.551166  126.849506
# 4   10050    Seoul        Gwanak-gu  37.478290  126.951502
# 5   10060    Seoul      Gwangjin-gu  37.538712  127.082366
# 6   10070    Seoul          Guro-gu  37.495632  126.887650
# 7   10080    Seoul     Geumcheon-gu  37.456852  126.895229
# 8   10090    Seoul         Nowon-gu  37.654259  127.056294
# 9   10100    Seoul        Dobong-gu  37.668952  127.047082
# 10  10110    Seoul    Dongdaemun-gu  37.574552  127.039721
# 11  10120    Seoul       Dongjak-gu  37.510571  126.963604
# 12  10130    Seoul          Mapo-gu  37.566283  126.901644
# 13  10140    Seoul     Seodaemun-gu  37.579428  126.936771
# 14  10150    Seoul        Seocho-gu  37.483804  127.032693
# 15  10160    Seoul     Seongdong-gu  37.563277  127.036647
# 16  10170    Seoul      Seongbuk-gu  37.589562  127.016700
# 17  10180    Seoul        Songpa-gu  37.514620  127.106141
# 18  10190    Seoul     Yangcheon-gu  37.517189  126.866618
# 19  10200    Seoul  Yeongdeungpo-gu  37.526505  126.896190
# 20  10210    Seoul       Yongsan-gu  37.532768  126.990021
# 21  10220    Seoul     Eunpyeong-gu  37.603481  126.929173
# 22  10230    Seoul        Jongno-gu  37.572999  126.979189
# 23  10240    Seoul          Jung-gu  37.563988  126.997530
# 24  10250    Seoul      Jungnang-gu  37.606832  127.092656
#
#     elementary_school_count  kindergarten_count  university_count  \
# 0                        33                  38                 0
# 1                        27                  32                 0
# 2                        14                  21                 0
# 3                        36                  56                 1
# 4                        22                  33                 1
# 5                        22                  33                 3
# 6                        26                  34                 3
# 7                        18                  19                 0
# 8                        42                  66                 6
# 9                        23                  26                 1
# 10                       21                  31                 4
# 11                       21                  34                 3
# 12                       22                  24                 2
# 13                       19                  25                 6
# 14                       24                  27                 1
# 15                       21                  30                 2
# 16                       29                  49                 6
# 17                       40                  51                 1
# 18                       30                  43                 0
# 19                       23                  39                 0
# 20                       15                  13                 1
# 21                       31                  44                 1
# 22                       13                  17                 3
# 23                       12                  14                 2
# 24                       23                  31                 1
#
#     academy_ratio  elderly_population_ratio  elderly_alone_ratio  \
# 0            4.18                     13.17                  4.3
# 1            1.54                     14.55                  5.4
# 2            0.67                     19.49                  8.5
# 3            1.17                     14.39                  5.7
# 4            0.89                     15.12                  4.9
# 5            1.16                     13.75                  4.8
# 6            1.00                     16.21                  5.7
# 7            0.96                     16.15                  6.7
# 8            1.39                     15.40                  7.4
# 9            0.95                     17.89                  7.2
# 10           1.06                     17.26                  6.7
# 11           1.17                     15.85                  5.2
# 12           1.83                     14.05                  4.9
# 13           1.12                     16.77                  6.2
# 14           2.60                     13.39                  3.8
# 15           0.97                     14.76                  5.3
# 16           1.02                     16.15                  6.0
# 17           1.65                     13.10                  4.1
# 18           2.26                     13.55                  5.5
# 19           1.21                     15.60                  5.8
# 20           0.68                     16.87                  6.5
# 21           1.09                     17.00                  6.5
# 22           1.71                     18.27                  6.8
# 23           0.94                     18.42                  7.4
# 24           0.70                     16.65                  6.9
#
#     nursing_home_count  patient_id
# 0                 3088          83
# 1                 1023          35
# 2                  628          24
# 3                 1080          78
# 4                  909         113
# 5                  723          17
# 6                  741          85
# 7                  475          32
# 8                  952          43
# 9                  485          62
# 10                 832          38
# 11                 762          53
# 12                 929          38
# 13                 587          36
# 14                1465          55
# 15                 593          49
# 16                 729          33
# 17                1527          55
# 18                 816          71
# 19                1001          62
# 20                 435          50
# 21                 874          53
# 22                 668          22
# 23                 728          12
# 24                 689          33

# %%
# left outer join
# seoul_patients에는 없지만 region_seoul에 있는데이터도 출력

pd.merge(region_seoul, seoul_patients, on='city', how = 'left')
# Out:
#      code province             city   latitude   longitude  \
# 0   10000    Seoul            Seoul  37.566953  126.977977
# 1   10010    Seoul       Gangnam-gu  37.518421  127.047222
# 2   10020    Seoul      Gangdong-gu  37.530492  127.123837
# 3   10030    Seoul       Gangbuk-gu  37.639938  127.025508
# 4   10040    Seoul       Gangseo-gu  37.551166  126.849506
# 5   10050    Seoul        Gwanak-gu  37.478290  126.951502
# 6   10060    Seoul      Gwangjin-gu  37.538712  127.082366
# 7   10070    Seoul          Guro-gu  37.495632  126.887650
# 8   10080    Seoul     Geumcheon-gu  37.456852  126.895229
# 9   10090    Seoul         Nowon-gu  37.654259  127.056294
# 10  10100    Seoul        Dobong-gu  37.668952  127.047082
# 11  10110    Seoul    Dongdaemun-gu  37.574552  127.039721
# 12  10120    Seoul       Dongjak-gu  37.510571  126.963604
# 13  10130    Seoul          Mapo-gu  37.566283  126.901644
# 14  10140    Seoul     Seodaemun-gu  37.579428  126.936771
# 15  10150    Seoul        Seocho-gu  37.483804  127.032693
# 16  10160    Seoul     Seongdong-gu  37.563277  127.036647
# 17  10170    Seoul      Seongbuk-gu  37.589562  127.016700
# 18  10180    Seoul        Songpa-gu  37.514620  127.106141
# 19  10190    Seoul     Yangcheon-gu  37.517189  126.866618
# 20  10200    Seoul  Yeongdeungpo-gu  37.526505  126.896190
# 21  10210    Seoul       Yongsan-gu  37.532768  126.990021
# 22  10220    Seoul     Eunpyeong-gu  37.603481  126.929173
# 23  10230    Seoul        Jongno-gu  37.572999  126.979189
# 24  10240    Seoul          Jung-gu  37.563988  126.997530
# 25  10250    Seoul      Jungnang-gu  37.606832  127.092656
#
#     elementary_school_count  kindergarten_count  university_count  \
# 0                       607                 830                48
# 1                        33                  38                 0
# 2                        27                  32                 0
# 3                        14                  21                 0
# 4                        36                  56                 1
# 5                        22                  33                 1
# 6                        22                  33                 3
# 7                        26                  34                 3
# 8                        18                  19                 0
# 9                        42                  66                 6
# 10                       23                  26                 1
# 11                       21                  31                 4
# 12                       21                  34                 3
# 13                       22                  24                 2
# 14                       19                  25                 6
# 15                       24                  27                 1
# 16                       21                  30                 2
# 17                       29                  49                 6
# 18                       40                  51                 1
# 19                       30                  43                 0
# 20                       23                  39                 0
# 21                       15                  13                 1
# 22                       31                  44                 1
# 23                       13                  17                 3
# 24                       12                  14                 2
# 25                       23                  31                 1
#
#     academy_ratio  elderly_population_ratio  elderly_alone_ratio  \
# 0            1.44                     15.38                  5.8
# 1            4.18                     13.17                  4.3
# 2            1.54                     14.55                  5.4
# 3            0.67                     19.49                  8.5
# 4            1.17                     14.39                  5.7
# 5            0.89                     15.12                  4.9
# 6            1.16                     13.75                  4.8
# 7            1.00                     16.21                  5.7
# 8            0.96                     16.15                  6.7
# 9            1.39                     15.40                  7.4
# 10           0.95                     17.89                  7.2
# 11           1.06                     17.26                  6.7
# 12           1.17                     15.85                  5.2
# 13           1.83                     14.05                  4.9
# 14           1.12                     16.77                  6.2
# 15           2.60                     13.39                  3.8
# 16           0.97                     14.76                  5.3
# 17           1.02                     16.15                  6.0
# 18           1.65                     13.10                  4.1
# 19           2.26                     13.55                  5.5
# 20           1.21                     15.60                  5.8
# 21           0.68                     16.87                  6.5
# 22           1.09                     17.00                  6.5
# 23           1.71                     18.27                  6.8
# 24           0.94                     18.42                  7.4
# 25           0.70                     16.65                  6.9
#
#     nursing_home_count  patient_id
# 0                22739         NaN
# 1                 3088        83.0
# 2                 1023        35.0
# 3                  628        24.0
# 4                 1080        78.0
# 5                  909       113.0
# 6                  723        17.0
# 7                  741        85.0
# 8                  475        32.0
# 9                  952        43.0
# 10                 485        62.0
# 11                 832        38.0
# 12                 762        53.0
# 13                 929        38.0
# 14                 587        36.0
# 15                1465        55.0
# 16                 593        49.0
# 17                 729        33.0
# 18                1527        55.0
# 19                 816        71.0
# 20                1001        62.0
# 21                 435        50.0
# 22                 874        53.0
# 23                 668        22.0
# 24                 728        12.0
# 25                 689        33.0

# %%
# right outer join
# region_seoul에는 없지만 seoul_patients에 있는데이터도 출력

pd.merge(region_seoul, seoul_patients, on='city', how = 'right')
# Out:
#        code province             city   latitude   longitude  \
# 0   10100.0    Seoul        Dobong-gu  37.668952  127.047082
# 1   10110.0    Seoul    Dongdaemun-gu  37.574552  127.039721
# 2   10120.0    Seoul       Dongjak-gu  37.510571  126.963604
# 3   10220.0    Seoul     Eunpyeong-gu  37.603481  126.929173
# 4   10030.0    Seoul       Gangbuk-gu  37.639938  127.025508
# 5   10020.0    Seoul      Gangdong-gu  37.530492  127.123837
# 6   10010.0    Seoul       Gangnam-gu  37.518421  127.047222
# 7   10040.0    Seoul       Gangseo-gu  37.551166  126.849506
# 8   10080.0    Seoul     Geumcheon-gu  37.456852  126.895229
# 9   10070.0    Seoul          Guro-gu  37.495632  126.887650
# 10  10050.0    Seoul        Gwanak-gu  37.478290  126.951502
# 11  10060.0    Seoul      Gwangjin-gu  37.538712  127.082366
# 12  10230.0    Seoul        Jongno-gu  37.572999  126.979189
# 13  10240.0    Seoul          Jung-gu  37.563988  126.997530
# 14  10250.0    Seoul      Jungnang-gu  37.606832  127.092656
# 15  10130.0    Seoul          Mapo-gu  37.566283  126.901644
# 16  10090.0    Seoul         Nowon-gu  37.654259  127.056294
# 17  10150.0    Seoul        Seocho-gu  37.483804  127.032693
# 18  10140.0    Seoul     Seodaemun-gu  37.579428  126.936771
# 19  10170.0    Seoul      Seongbuk-gu  37.589562  127.016700
# 20  10160.0    Seoul     Seongdong-gu  37.563277  127.036647
# 21  10180.0    Seoul        Songpa-gu  37.514620  127.106141
# 22  10190.0    Seoul     Yangcheon-gu  37.517189  126.866618
# 23  10200.0    Seoul  Yeongdeungpo-gu  37.526505  126.896190
# 24  10210.0    Seoul       Yongsan-gu  37.532768  126.990021
# 25      NaN      NaN              etc        NaN         NaN
#
#     elementary_school_count  kindergarten_count  university_count  \
# 0                      23.0                26.0               1.0
# 1                      21.0                31.0               4.0
# 2                      21.0                34.0               3.0
# 3                      31.0                44.0               1.0
# 4                      14.0                21.0               0.0
# 5                      27.0                32.0               0.0
# 6                      33.0                38.0               0.0
# 7                      36.0                56.0               1.0
# 8                      18.0                19.0               0.0
# 9                      26.0                34.0               3.0
# 10                     22.0                33.0               1.0
# 11                     22.0                33.0               3.0
# 12                     13.0                17.0               3.0
# 13                     12.0                14.0               2.0
# 14                     23.0                31.0               1.0
# 15                     22.0                24.0               2.0
# 16                     42.0                66.0               6.0
# 17                     24.0                27.0               1.0
# 18                     19.0                25.0               6.0
# 19                     29.0                49.0               6.0
# 20                     21.0                30.0               2.0
# 21                     40.0                51.0               1.0
# 22                     30.0                43.0               0.0
# 23                     23.0                39.0               0.0
# 24                     15.0                13.0               1.0
# 25                      NaN                 NaN               NaN
#
#     academy_ratio  elderly_population_ratio  elderly_alone_ratio  \
# 0            0.95                     17.89                  7.2
# 1            1.06                     17.26                  6.7
# 2            1.17                     15.85                  5.2
# 3            1.09                     17.00                  6.5
# 4            0.67                     19.49                  8.5
# 5            1.54                     14.55                  5.4
# 6            4.18                     13.17                  4.3
# 7            1.17                     14.39                  5.7
# 8            0.96                     16.15                  6.7
# 9            1.00                     16.21                  5.7
# 10           0.89                     15.12                  4.9
# 11           1.16                     13.75                  4.8
# 12           1.71                     18.27                  6.8
# 13           0.94                     18.42                  7.4
# 14           0.70                     16.65                  6.9
# 15           1.83                     14.05                  4.9
# 16           1.39                     15.40                  7.4
# 17           2.60                     13.39                  3.8
# 18           1.12                     16.77                  6.2
# 19           1.02                     16.15                  6.0
# 20           0.97                     14.76                  5.3
# 21           1.65                     13.10                  4.1
# 22           2.26                     13.55                  5.5
# 23           1.21                     15.60                  5.8
# 24           0.68                     16.87                  6.5
# 25            NaN                       NaN                  NaN
#
#     nursing_home_count  patient_id
# 0                485.0          62
# 1                832.0          38
# 2                762.0          53
# 3                874.0          53
# 4                628.0          24
# 5               1023.0          35
# 6               3088.0          83
# 7               1080.0          78
# 8                475.0          32
# 9                741.0          85
# 10               909.0         113
# 11               723.0          17
# 12               668.0          22
# 13               728.0          12
# 14               689.0          33
# 15               929.0          38
# 16               952.0          43
# 17              1465.0          55
# 18               587.0          36
# 19               729.0          33
# 20               593.0          49
# 21              1527.0          55
# 22               816.0          71
# 23              1001.0          62
# 24               435.0          50
# 25                 NaN          80

# %%
# full outer join
# 모든 데이터들을 출력

pd.merge(region_seoul, seoul_patients, on='city', how = 'outer')
# Out:
#        code province             city   latitude   longitude  \
# 0   10000.0    Seoul            Seoul  37.566953  126.977977
# 1   10010.0    Seoul       Gangnam-gu  37.518421  127.047222
# 2   10020.0    Seoul      Gangdong-gu  37.530492  127.123837
# 3   10030.0    Seoul       Gangbuk-gu  37.639938  127.025508
# 4   10040.0    Seoul       Gangseo-gu  37.551166  126.849506
# 5   10050.0    Seoul        Gwanak-gu  37.478290  126.951502
# 6   10060.0    Seoul      Gwangjin-gu  37.538712  127.082366
# 7   10070.0    Seoul          Guro-gu  37.495632  126.887650
# 8   10080.0    Seoul     Geumcheon-gu  37.456852  126.895229
# 9   10090.0    Seoul         Nowon-gu  37.654259  127.056294
# 10  10100.0    Seoul        Dobong-gu  37.668952  127.047082
# 11  10110.0    Seoul    Dongdaemun-gu  37.574552  127.039721
# 12  10120.0    Seoul       Dongjak-gu  37.510571  126.963604
# 13  10130.0    Seoul          Mapo-gu  37.566283  126.901644
# 14  10140.0    Seoul     Seodaemun-gu  37.579428  126.936771
# 15  10150.0    Seoul        Seocho-gu  37.483804  127.032693
# 16  10160.0    Seoul     Seongdong-gu  37.563277  127.036647
# 17  10170.0    Seoul      Seongbuk-gu  37.589562  127.016700
# 18  10180.0    Seoul        Songpa-gu  37.514620  127.106141
# 19  10190.0    Seoul     Yangcheon-gu  37.517189  126.866618
# 20  10200.0    Seoul  Yeongdeungpo-gu  37.526505  126.896190
# 21  10210.0    Seoul       Yongsan-gu  37.532768  126.990021
# 22  10220.0    Seoul     Eunpyeong-gu  37.603481  126.929173
# 23  10230.0    Seoul        Jongno-gu  37.572999  126.979189
# 24  10240.0    Seoul          Jung-gu  37.563988  126.997530
# 25  10250.0    Seoul      Jungnang-gu  37.606832  127.092656
# 26      NaN      NaN              etc        NaN         NaN
#
#     elementary_school_count  kindergarten_count  university_count  \
# 0                     607.0               830.0              48.0
# 1                      33.0                38.0               0.0
# 2                      27.0                32.0               0.0
# 3                      14.0                21.0               0.0
# 4                      36.0                56.0               1.0
# 5                      22.0                33.0               1.0
# 6                      22.0                33.0               3.0
# 7                      26.0                34.0               3.0
# 8                      18.0                19.0               0.0
# 9                      42.0                66.0               6.0
# 10                     23.0                26.0               1.0
# 11                     21.0                31.0               4.0
# 12                     21.0                34.0               3.0
# 13                     22.0                24.0               2.0
# 14                     19.0                25.0               6.0
# 15                     24.0                27.0               1.0
# 16                     21.0                30.0               2.0
# 17                     29.0                49.0               6.0
# 18                     40.0                51.0               1.0
# 19                     30.0                43.0               0.0
# 20                     23.0                39.0               0.0
# 21                     15.0                13.0               1.0
# 22                     31.0                44.0               1.0
# 23                     13.0                17.0               3.0
# 24                     12.0                14.0               2.0
# 25                     23.0                31.0               1.0
# 26                      NaN                 NaN               NaN
#
#     academy_ratio  elderly_population_ratio  elderly_alone_ratio  \
# 0            1.44                     15.38                  5.8
# 1            4.18                     13.17                  4.3
# 2            1.54                     14.55                  5.4
# 3            0.67                     19.49                  8.5
# 4            1.17                     14.39                  5.7
# 5            0.89                     15.12                  4.9
# 6            1.16                     13.75                  4.8
# 7            1.00                     16.21                  5.7
# 8            0.96                     16.15                  6.7
# 9            1.39                     15.40                  7.4
# 10           0.95                     17.89                  7.2
# 11           1.06                     17.26                  6.7
# 12           1.17                     15.85                  5.2
# 13           1.83                     14.05                  4.9
# 14           1.12                     16.77                  6.2
# 15           2.60                     13.39                  3.8
# 16           0.97                     14.76                  5.3
# 17           1.02                     16.15                  6.0
# 18           1.65                     13.10                  4.1
# 19           2.26                     13.55                  5.5
# 20           1.21                     15.60                  5.8
# 21           0.68                     16.87                  6.5
# 22           1.09                     17.00                  6.5
# 23           1.71                     18.27                  6.8
# 24           0.94                     18.42                  7.4
# 25           0.70                     16.65                  6.9
# 26            NaN                       NaN                  NaN
#
#     nursing_home_count  patient_id
# 0              22739.0         NaN
# 1               3088.0        83.0
# 2               1023.0        35.0
# 3                628.0        24.0
# 4               1080.0        78.0
# 5                909.0       113.0
# 6                723.0        17.0
# 7                741.0        85.0
# 8                475.0        32.0
# 9                952.0        43.0
# 10               485.0        62.0
# 11               832.0        38.0
# 12               762.0        53.0
# 13               929.0        38.0
# 14               587.0        36.0
# 15              1465.0        55.0
# 16               593.0        49.0
# 17               729.0        33.0
# 18              1527.0        55.0
# 19               816.0        71.0
# 20              1001.0        62.0
# 21               435.0        50.0
# 22               874.0        53.0
# 23               668.0        22.0
# 24               728.0        12.0
# 25               689.0        33.0
# 26                 NaN        80.0

# %%
# index가 다른 경우
# seoul_patients의 컬럼명을 city에서 town으로 바꿈

seoul_patients.columns = ['town', 'patient_id']
seoul_patients.columns
# Out:
# Index(['town', 'patient_id'], dtype='object')

# %%
# left_on, right_on을 이용

pd.merge(region_seoul, seoul_patients, 
         left_on = 'city', right_on = 'town', how = 'inner')
# Out:
#      code province             city   latitude   longitude  \
# 0   10010    Seoul       Gangnam-gu  37.518421  127.047222
# 1   10020    Seoul      Gangdong-gu  37.530492  127.123837
# 2   10030    Seoul       Gangbuk-gu  37.639938  127.025508
# 3   10040    Seoul       Gangseo-gu  37.551166  126.849506
# 4   10050    Seoul        Gwanak-gu  37.478290  126.951502
# 5   10060    Seoul      Gwangjin-gu  37.538712  127.082366
# 6   10070    Seoul          Guro-gu  37.495632  126.887650
# 7   10080    Seoul     Geumcheon-gu  37.456852  126.895229
# 8   10090    Seoul         Nowon-gu  37.654259  127.056294
# 9   10100    Seoul        Dobong-gu  37.668952  127.047082
# 10  10110    Seoul    Dongdaemun-gu  37.574552  127.039721
# 11  10120    Seoul       Dongjak-gu  37.510571  126.963604
# 12  10130    Seoul          Mapo-gu  37.566283  126.901644
# 13  10140    Seoul     Seodaemun-gu  37.579428  126.936771
# 14  10150    Seoul        Seocho-gu  37.483804  127.032693
# 15  10160    Seoul     Seongdong-gu  37.563277  127.036647
# 16  10170    Seoul      Seongbuk-gu  37.589562  127.016700
# 17  10180    Seoul        Songpa-gu  37.514620  127.106141
# 18  10190    Seoul     Yangcheon-gu  37.517189  126.866618
# 19  10200    Seoul  Yeongdeungpo-gu  37.526505  126.896190
# 20  10210    Seoul       Yongsan-gu  37.532768  126.990021
# 21  10220    Seoul     Eunpyeong-gu  37.603481  126.929173
# 22  10230    Seoul        Jongno-gu  37.572999  126.979189
# 23  10240    Seoul          Jung-gu  37.563988  126.997530
# 24  10250    Seoul      Jungnang-gu  37.606832  127.092656
#
#     elementary_school_count  kindergarten_count  university_count  \
# 0                        33                  38                 0
# 1                        27                  32                 0
# 2                        14                  21                 0
# 3                        36                  56                 1
# 4                        22                  33                 1
# 5                        22                  33                 3
# 6                        26                  34                 3
# 7                        18                  19                 0
# 8                        42                  66                 6
# 9                        23                  26                 1
# 10                       21                  31                 4
# 11                       21                  34                 3
# 12                       22                  24                 2
# 13                       19                  25                 6
# 14                       24                  27                 1
# 15                       21                  30                 2
# 16                       29                  49                 6
# 17                       40                  51                 1
# 18                       30                  43                 0
# 19                       23                  39                 0
# 20                       15                  13                 1
# 21                       31                  44                 1
# 22                       13                  17                 3
# 23                       12                  14                 2
# 24                       23                  31                 1
#
#     academy_ratio  elderly_population_ratio  elderly_alone_ratio  \
# 0            4.18                     13.17                  4.3
# 1            1.54                     14.55                  5.4
# 2            0.67                     19.49                  8.5
# 3            1.17                     14.39                  5.7
# 4            0.89                     15.12                  4.9
# 5            1.16                     13.75                  4.8
# 6            1.00                     16.21                  5.7
# 7            0.96                     16.15                  6.7
# 8            1.39                     15.40                  7.4
# 9            0.95                     17.89                  7.2
# 10           1.06                     17.26                  6.7
# 11           1.17                     15.85                  5.2
# 12           1.83                     14.05                  4.9
# 13           1.12                     16.77                  6.2
# 14           2.60                     13.39                  3.8
# 15           0.97                     14.76                  5.3
# 16           1.02                     16.15                  6.0
# 17           1.65                     13.10                  4.1
# 18           2.26                     13.55                  5.5
# 19           1.21                     15.60                  5.8
# 20           0.68                     16.87                  6.5
# 21           1.09                     17.00                  6.5
# 22           1.71                     18.27                  6.8
# 23           0.94                     18.42                  7.4
# 24           0.70                     16.65                  6.9
#
#     nursing_home_count             town  patient_id
# 0                 3088       Gangnam-gu          83
# 1                 1023      Gangdong-gu          35
# 2                  628       Gangbuk-gu          24
# 3                 1080       Gangseo-gu          78
# 4                  909        Gwanak-gu         113
# 5                  723      Gwangjin-gu          17
# 6                  741          Guro-gu          85
# 7                  475     Geumcheon-gu          32
# 8                  952         Nowon-gu          43
# 9                  485        Dobong-gu          62
# 10                 832    Dongdaemun-gu          38
# 11                 762       Dongjak-gu          53
# 12                 929          Mapo-gu          38
# 13                 587     Seodaemun-gu          36
# 14                1465        Seocho-gu          55
# 15                 593     Seongdong-gu          49
# 16                 729      Seongbuk-gu          33
# 17                1527        Songpa-gu          55
# 18                 816     Yangcheon-gu          71
# 19                1001  Yeongdeungpo-gu          62
# 20                 435       Yongsan-gu          50
# 21                 874     Eunpyeong-gu          53
# 22                 668        Jongno-gu          22
# 23                 728          Jung-gu          12
# 24                 689      Jungnang-gu          33

# %%
# 서울 지역구별로 확진자수 조회

seoul_patients = seoul_patientInfo.groupby('city').count()[['patient_id']]
seoul_patients.head()
# Out:
#                patient_id
# city
# Dobong-gu              62
# Dongdaemun-gu          38
# Dongjak-gu             53
# Eunpyeong-gu           53
# Gangbuk-gu             24

# %%
# 컬럼말고 index를 기준으로 조인
# right_index, left_index를 이용한 join

pd.merge(region_seoul, seoul_patients, 
         left_on = 'city', right_index = True, how = 'inner')
# Out:
#      code province             city   latitude   longitude  \
# 1   10010    Seoul       Gangnam-gu  37.518421  127.047222
# 2   10020    Seoul      Gangdong-gu  37.530492  127.123837
# 3   10030    Seoul       Gangbuk-gu  37.639938  127.025508
# 4   10040    Seoul       Gangseo-gu  37.551166  126.849506
# 5   10050    Seoul        Gwanak-gu  37.478290  126.951502
# 6   10060    Seoul      Gwangjin-gu  37.538712  127.082366
# 7   10070    Seoul          Guro-gu  37.495632  126.887650
# 8   10080    Seoul     Geumcheon-gu  37.456852  126.895229
# 9   10090    Seoul         Nowon-gu  37.654259  127.056294
# 10  10100    Seoul        Dobong-gu  37.668952  127.047082
# 11  10110    Seoul    Dongdaemun-gu  37.574552  127.039721
# 12  10120    Seoul       Dongjak-gu  37.510571  126.963604
# 13  10130    Seoul          Mapo-gu  37.566283  126.901644
# 14  10140    Seoul     Seodaemun-gu  37.579428  126.936771
# 15  10150    Seoul        Seocho-gu  37.483804  127.032693
# 16  10160    Seoul     Seongdong-gu  37.563277  127.036647
# 17  10170    Seoul      Seongbuk-gu  37.589562  127.016700
# 18  10180    Seoul        Songpa-gu  37.514620  127.106141
# 19  10190    Seoul     Yangcheon-gu  37.517189  126.866618
# 20  10200    Seoul  Yeongdeungpo-gu  37.526505  126.896190
# 21  10210    Seoul       Yongsan-gu  37.532768  126.990021
# 22  10220    Seoul     Eunpyeong-gu  37.603481  126.929173
# 23  10230    Seoul        Jongno-gu  37.572999  126.979189
# 24  10240    Seoul          Jung-gu  37.563988  126.997530
# 25  10250    Seoul      Jungnang-gu  37.606832  127.092656
#
#     elementary_school_count  kindergarten_count  university_count  \
# 1                        33                  38                 0
# 2                        27                  32                 0
# 3                        14                  21                 0
# 4                        36                  56                 1
# 5                        22                  33                 1
# 6                        22                  33                 3
# 7                        26                  34                 3
# 8                        18                  19                 0
# 9                        42                  66                 6
# 10                       23                  26                 1
# 11                       21                  31                 4
# 12                       21                  34                 3
# 13                       22                  24                 2
# 14                       19                  25                 6
# 15                       24                  27                 1
# 16                       21                  30                 2
# 17                       29                  49                 6
# 18                       40                  51                 1
# 19                       30                  43                 0
# 20                       23                  39                 0
# 21                       15                  13                 1
# 22                       31                  44                 1
# 23                       13                  17                 3
# 24                       12                  14                 2
# 25                       23                  31                 1
#
#     academy_ratio  elderly_population_ratio  elderly_alone_ratio  \
# 1            4.18                     13.17                  4.3
# 2            1.54                     14.55                  5.4
# 3            0.67                     19.49                  8.5
# 4            1.17                     14.39                  5.7
# 5            0.89                     15.12                  4.9
# 6            1.16                     13.75                  4.8
# 7            1.00                     16.21                  5.7
# 8            0.96                     16.15                  6.7
# 9            1.39                     15.40                  7.4
# 10           0.95                     17.89                  7.2
# 11           1.06                     17.26                  6.7
# 12           1.17                     15.85                  5.2
# 13           1.83                     14.05                  4.9
# 14           1.12                     16.77                  6.2
# 15           2.60                     13.39                  3.8
# 16           0.97                     14.76                  5.3
# 17           1.02                     16.15                  6.0
# 18           1.65                     13.10                  4.1
# 19           2.26                     13.55                  5.5
# 20           1.21                     15.60                  5.8
# 21           0.68                     16.87                  6.5
# 22           1.09                     17.00                  6.5
# 23           1.71                     18.27                  6.8
# 24           0.94                     18.42                  7.4
# 25           0.70                     16.65                  6.9
#
#     nursing_home_count  patient_id
# 1                 3088          83
# 2                 1023          35
# 3                  628          24
# 4                 1080          78
# 5                  909         113
# 6                  723          17
# 7                  741          85
# 8                  475          32
# 9                  952          43
# 10                 485          62
# 11                 832          38
# 12                 762          53
# 13                 929          38
# 14                 587          36
# 15                1465          55
# 16                 593          49
# 17                 729          33
# 18                1527          55
# 19                 816          71
# 20                1001          62
# 21                 435          50
# 22                 874          53
# 23                 668          22
# 24                 728          12
# 25                 689          33

# %% [markdown]
# ## 실습3. patient_ele, region_ele는 각각 전국 자치구별 환자수, 지역 정보입니다
#
# ## - province 컬럼을 기준으로 inner join하기

# %%
patient_ele = patientInfo.groupby('province').count()['patient_id'].reset_index()
region_ele = region.groupby('province').sum().reset_index().drop(columns = ['code','latitude','longitude'])

# %%
# 아래와 같은 결과가 나오면 됩니다!!
pd.merge(patient_ele, region_ele, 
         left_on = 'province', right_on = 'province', how = 'inner')
# Out:
#              province  patient_id  elementary_school_count  \
# 0               Busan         151                      608
# 1   Chungcheongbuk-do          56                      518
# 2   Chungcheongnam-do         168                      818
# 3               Daegu         137                      458
# 4             Daejeon         119                      296
# 5          Gangwon-do          63                      698
# 6             Gwangju          44                      310
# 7         Gyeonggi-do        1208                     2554
# 8    Gyeongsangbuk-do        1254                      942
# 9    Gyeongsangnam-do         133                     1002
# 10            Incheon         343                      500
# 11            Jeju-do          19                      113
# 12       Jeollabuk-do          27                      838
# 13       Jeollanam-do          25                      858
# 14             Sejong          51                       48
# 15              Seoul        1312                     1214
# 16              Ulsan          55                      238
#
#     kindergarten_count  university_count  academy_ratio  \
# 0                  816                44          22.57
# 1                  656                34          12.28
# 2                  998                42          17.96
# 3                  710                22          15.42
# 4                  520                30           8.55
# 5                  736                36          21.22
# 6                  624                34          14.84
# 7                 4474               122          45.46
# 8                 1414                66          22.77
# 9                 1372                42          25.90
# 10                 806                14          11.60
# 11                 123                 4           1.53
# 12                1038                38          19.95
# 13                1084                38          24.50
# 14                  60                 3           1.78
# 15                1660                96          35.36
# 16                 400                 8          12.67
#
#     elderly_population_ratio  elderly_alone_ratio  nursing_home_count
# 0                     329.08                154.6               13504
# 1                     278.31                141.9                5538
# 2                     381.51                187.3                7282
# 3                     153.28                 71.7               10166
# 4                      86.26                 37.2                5968
# 5                     434.92                220.0                5038
# 6                      88.89                 40.3                5704
# 7                     461.75                194.7               40982
# 8                     661.35                363.2                8948
# 9                     470.24                279.7               10728
# 10                    180.39                 79.6                8994
# 11                     15.10                  6.4                1245
# 12                    412.06                233.0                7548
# 13                    647.27                391.7                6778
# 14                      9.48                  3.8                 491
# 15                    409.19                154.0               45478
# 16                     70.64                 31.0                3602

# %% [markdown]
# ## 실습4. region_ele는 자치구 데이터뿐만 아니라 전국데이터도 포함되어있습니다.
#
# ## - province 컬럼을 기준으로 right outer join하기

# %%
# 아래와 같은 결과가 나오면 됩니다!!
pd.merge(patient_ele, region_ele, 
         left_on = 'province', right_on = 'province', how = 'right')
# Out:
#              province  patient_id  elementary_school_count  \
# 0               Busan       151.0                      608
# 1   Chungcheongbuk-do        56.0                      518
# 2   Chungcheongnam-do       168.0                      818
# 3               Daegu       137.0                      458
# 4             Daejeon       119.0                      296
# 5          Gangwon-do        63.0                      698
# 6             Gwangju        44.0                      310
# 7         Gyeonggi-do      1208.0                     2554
# 8    Gyeongsangbuk-do      1254.0                      942
# 9    Gyeongsangnam-do       133.0                     1002
# 10            Incheon       343.0                      500
# 11            Jeju-do        19.0                      113
# 12       Jeollabuk-do        27.0                      838
# 13       Jeollanam-do        25.0                      858
# 14              Korea         NaN                     6087
# 15             Sejong        51.0                       48
# 16              Seoul      1312.0                     1214
# 17              Ulsan        55.0                      238
#
#     kindergarten_count  university_count  academy_ratio  \
# 0                  816                44          22.57
# 1                  656                34          12.28
# 2                  998                42          17.96
# 3                  710                22          15.42
# 4                  520                30           8.55
# 5                  736                36          21.22
# 6                  624                34          14.84
# 7                 4474               122          45.46
# 8                 1414                66          22.77
# 9                 1372                42          25.90
# 10                 806                14          11.60
# 11                 123                 4           1.53
# 12                1038                38          19.95
# 13                1084                38          24.50
# 14                8837               340           1.56
# 15                  60                 3           1.78
# 16                1660                96          35.36
# 17                 400                 8          12.67
#
#     elderly_population_ratio  elderly_alone_ratio  nursing_home_count
# 0                     329.08                154.6               13504
# 1                     278.31                141.9                5538
# 2                     381.51                187.3                7282
# 3                     153.28                 71.7               10166
# 4                      86.26                 37.2                5968
# 5                     434.92                220.0                5038
# 6                      88.89                 40.3                5704
# 7                     461.75                194.7               40982
# 8                     661.35                363.2                8948
# 9                     470.24                279.7               10728
# 10                    180.39                 79.6                8994
# 11                     15.10                  6.4                1245
# 12                    412.06                233.0                7548
# 13                    647.27                391.7                6778
# 14                     15.67                  7.2               94865
# 15                      9.48                  3.8                 491
# 16                    409.19                154.0               45478
# 17                     70.64                 31.0                3602

# %% [markdown]
# ## pivot_table
#
# - 엑셀의 pivot_table 기능처럼 사용
#
#
# - 데이터프레임.pivot_table(index, values, columns, aggfunc)
#     - index는 필수
#     - index에는 그룹화하고 싶은 컬럼 넣으면 됨(두개이상이면 list로)
#     - 만약 특정 컬럼에 대한 통계량을 보고싶으면 values 이용
#     - 추가로 구분하고싶은 컬럼있으면 columns 이용
#     - aggfunc은 조회하고 싶은 통계량 조회, default는 mean

# %%
# 서울시 유동인구

seoulfloating
# Out:
#                date  hour  birth_year     sex province           city  fp_num
# 0        2020-01-01     0          20  female    Seoul      Dobong-gu   19140
# 1        2020-01-01     0          20    male    Seoul      Dobong-gu   19950
# 2        2020-01-01     0          20  female    Seoul  Dongdaemun-gu   25450
# 3        2020-01-01     0          20    male    Seoul  Dongdaemun-gu   27050
# 4        2020-01-01     0          20  female    Seoul     Dongjag-gu   28880
# ...             ...   ...         ...     ...      ...            ...     ...
# 1084795  2020-05-31    21          40  female    Seoul      Dobong-gu   27620
# 1084796  2020-05-31    21          40  female    Seoul      Songpa-gu   56560
# 1084797  2020-05-31    21          50  female    Seoul    Gangdong-gu   38960
# 1084798  2020-05-31    22          60  female    Seoul        Guro-gu   25420
# 1084799  2020-05-31    23          40    male    Seoul   Eunpyeong-gu   38650
#
# [1084800 rows x 7 columns]

# %%
# date와 city로 그룹화

seoulfloating.pivot_table(index = ['date', 'city'])
# Out:
#                             birth_year        fp_num  hour
# date       city
# 2020-01-01 Dobong-gu                45  21824.409722  11.5
#            Dongdaemun-gu            45  24022.534722  11.5
#            Dongjag-gu               45  26628.576389  11.5
#            Eunpyeong-gu             45  30489.340278  11.5
#            Gangbuk-gu               45  21391.006944  11.5
# ...                                ...           ...   ...
# 2020-05-31 Seongdong-gu             45  19659.965278  11.5
#            Songpa-gu                45  42232.881944  11.5
#            Yangcheon-gu             45  28259.062500  11.5
#            Yeongdeungpo-gu          45  28785.277778  11.5
#            Yongsan-gu               45  16030.902778  11.5
#
# [3775 rows x 3 columns]

# %%
# date와 city로 그룹화하고 유동인구의 합 조회

seoulfloating.pivot_table(index = ['date', 'city'], values = 'fp_num', aggfunc = 'sum')
# Out:
#                               fp_num
# date       city
# 2020-01-01 Dobong-gu         6285430
#            Dongdaemun-gu     6918490
#            Dongjag-gu        7669030
#            Eunpyeong-gu      8780930
#            Gangbuk-gu        6160610
# ...                              ...
# 2020-05-31 Seongdong-gu      5662070
#            Songpa-gu        12163070
#            Yangcheon-gu      8138610
#            Yeongdeungpo-gu   8290160
#            Yongsan-gu        4616900
#
# [3775 rows x 1 columns]

# %%
# date로 그룹화하고 city를 구분해서 합계 조회 

seoulfloating.pivot_table(index = 'date', columns = 'city', values = 'fp_num',
                          aggfunc = 'sum')
# Out:
# city        Dobong-gu  Dongdaemun-gu  Dongjag-gu  Eunpyeong-gu  Gangbuk-gu  \
# date
# 2020-01-01    6285430        6918490     7669030       8780930     6160610
# 2020-01-02    5674220        6989170     7465090       7901040     5634030
# 2020-01-03    5601640        6994200     7474610       7824170     5604240
# 2020-01-04    6005300        7045120     7741980       8464390     5952680
# 2020-01-05    6253260        7102720     7757170       8686730     6101710
# ...               ...            ...         ...           ...         ...
# 2020-05-27    5523470        6984010     7422880       7710210     5495020
# 2020-05-28    5517890        6981200     7410110       7711610     5485320
# 2020-05-29    3863340        4921780     5178630       5400700     3831210
# 2020-05-30    5845120        6819990     7534280       8249540     5768720
# 2020-05-31    6079620        6843670     7562690       8467980     5912230
#
# city        Gangdong-gu  Gangnam-gu  Gangseo-gu  Geumcheon-gu  Guro-gu  ...  \
# date                                                                    ...
# 2020-01-01      8296230    11001340    10998410       4990670  8605430  ...
# 2020-01-02      7933530    15751250    10676170       5802770  8760520  ...
# 2020-01-03      7924490    16034360    10632520       5712000  8674290  ...
# 2020-01-04      8237950    12944420    10858450       4942510  8566630  ...
# 2020-01-05      8402030    11822840    10963500       4957360  8705360  ...
# ...                 ...         ...         ...           ...      ...  ...
# 2020-05-27      7773150    15314740    10438080       5670870  8493490  ...
# 2020-05-28      7779000    15337040    10425070       5652870  8497310  ...
# 2020-05-29      5472280    11007760     7366570       4060480  5973500  ...
# 2020-05-30      7996910    12229270    10459100       4800670  8177060  ...
# 2020-05-31      8119920    11175450    10576080       4830890  8289630  ...
#
# city        Mapo-gu  Nowon-gu  Seocho-gu  Seodaemun-gu  Seongbuk-gu  \
# date
# 2020-01-01  7685110  10180430    8238170       6068870      8327910
# 2020-01-02  8363570   9356350   10729750       6239170      7900440
# 2020-01-03  8511950   9317260   10891610       6242510      7846680
# 2020-01-04  8247720   9995770    9378300       6194480      8191000
# 2020-01-05  7916840  10197320    8796060       6160290      8398280
# ...             ...       ...        ...           ...          ...
# 2020-05-27  8300840   9242830   10532760       6058570      8015820
# 2020-05-28  8301340   9238570   10548220       6063250      8008210
# 2020-05-29  5820760   6458910    7598330       4253450      5605280
# 2020-05-30  7841600   9750510    8944550       5922110      8149970
# 2020-05-31  7656140   9967490    8362590       5931200      8306880
#
# city        Seongdong-gu  Songpa-gu  Yangcheon-gu  Yeongdeungpo-gu  Yongsan-gu
# date
# 2020-01-01       5705250   12573680       8334990          8429420     4891430
# 2020-01-02       6302820   12776490       7811270         10122630     5352050
# 2020-01-03       6309900   12817800       7740920         10135000     5422740
# 2020-01-04       5894740   12779500       8194100          8837490     5174980
# 2020-01-05       5775070   12645940       8354430          8725190     5063560
# ...                  ...        ...           ...              ...         ...
# 2020-05-27       6314680   12498030       7606310          9927940     5177480
# 2020-05-28       6310410   12477800       7610580          9906720     5193920
# 2020-05-29       4468680    8801920       5329550          7080190     3694630
# 2020-05-30       5793170   12242600       7990820          8483270     4718410
# 2020-05-31       5662070   12163070       8138610          8290160     4616900
#
# [151 rows x 25 columns]

# %% [markdown]
# ## 실습5. SeoulFloating 데이터에서 유동인구의 합을 행은 날짜 열은 구로 구분하는 pivot_table을 만들기

# %%
# 아래와 같은 결과가 나오면 됩니다!!
seoulfloating.pivot_table(index = 'date', columns = 'city', values = 'fp_num',
                          aggfunc = 'sum')
# Out:
# city        Dobong-gu  Dongdaemun-gu  Dongjag-gu  Eunpyeong-gu  Gangbuk-gu  \
# date
# 2020-01-01    6285430        6918490     7669030       8780930     6160610
# 2020-01-02    5674220        6989170     7465090       7901040     5634030
# 2020-01-03    5601640        6994200     7474610       7824170     5604240
# 2020-01-04    6005300        7045120     7741980       8464390     5952680
# 2020-01-05    6253260        7102720     7757170       8686730     6101710
# ...               ...            ...         ...           ...         ...
# 2020-05-27    5523470        6984010     7422880       7710210     5495020
# 2020-05-28    5517890        6981200     7410110       7711610     5485320
# 2020-05-29    3863340        4921780     5178630       5400700     3831210
# 2020-05-30    5845120        6819990     7534280       8249540     5768720
# 2020-05-31    6079620        6843670     7562690       8467980     5912230
#
# city        Gangdong-gu  Gangnam-gu  Gangseo-gu  Geumcheon-gu  Guro-gu  ...  \
# date                                                                    ...
# 2020-01-01      8296230    11001340    10998410       4990670  8605430  ...
# 2020-01-02      7933530    15751250    10676170       5802770  8760520  ...
# 2020-01-03      7924490    16034360    10632520       5712000  8674290  ...
# 2020-01-04      8237950    12944420    10858450       4942510  8566630  ...
# 2020-01-05      8402030    11822840    10963500       4957360  8705360  ...
# ...                 ...         ...         ...           ...      ...  ...
# 2020-05-27      7773150    15314740    10438080       5670870  8493490  ...
# 2020-05-28      7779000    15337040    10425070       5652870  8497310  ...
# 2020-05-29      5472280    11007760     7366570       4060480  5973500  ...
# 2020-05-30      7996910    12229270    10459100       4800670  8177060  ...
# 2020-05-31      8119920    11175450    10576080       4830890  8289630  ...
#
# city        Mapo-gu  Nowon-gu  Seocho-gu  Seodaemun-gu  Seongbuk-gu  \
# date
# 2020-01-01  7685110  10180430    8238170       6068870      8327910
# 2020-01-02  8363570   9356350   10729750       6239170      7900440
# 2020-01-03  8511950   9317260   10891610       6242510      7846680
# 2020-01-04  8247720   9995770    9378300       6194480      8191000
# 2020-01-05  7916840  10197320    8796060       6160290      8398280
# ...             ...       ...        ...           ...          ...
# 2020-05-27  8300840   9242830   10532760       6058570      8015820
# 2020-05-28  8301340   9238570   10548220       6063250      8008210
# 2020-05-29  5820760   6458910    7598330       4253450      5605280
# 2020-05-30  7841600   9750510    8944550       5922110      8149970
# 2020-05-31  7656140   9967490    8362590       5931200      8306880
#
# city        Seongdong-gu  Songpa-gu  Yangcheon-gu  Yeongdeungpo-gu  Yongsan-gu
# date
# 2020-01-01       5705250   12573680       8334990          8429420     4891430
# 2020-01-02       6302820   12776490       7811270         10122630     5352050
# 2020-01-03       6309900   12817800       7740920         10135000     5422740
# 2020-01-04       5894740   12779500       8194100          8837490     5174980
# 2020-01-05       5775070   12645940       8354430          8725190     5063560
# ...                  ...        ...           ...              ...         ...
# 2020-05-27       6314680   12498030       7606310          9927940     5177480
# 2020-05-28       6310410   12477800       7610580          9906720     5193920
# 2020-05-29       4468680    8801920       5329550          7080190     3694630
# 2020-05-30       5793170   12242600       7990820          8483270     4718410
# 2020-05-31       5662070   12163070       8138610          8290160     4616900
#
# [151 rows x 25 columns]

# %% [markdown]
# ## unstack, stack
#
# - 계층적 인덱스가 있을때 사용
#     - 계층적 인덱스란 상위 인덱스, 하위 인덱스처럼 인덱스가 두개 이상 있음
#
#
# - stack
#     - 열을 행으로 바꿔줌
#     - 데이터프레임.stack()
#
#
# - unstack
#     - 행을 열으로 바꿔줌
#     - 데이터프레임.unstack()

# %%
# 계층적 인덱스의 예시
# values를 지정 안했기에 값이 여러개를 갖게 되어 계층이 생성됨.

seoul_pivot = seoulfloating.pivot_table(index = 'date', columns = 'city',
                          aggfunc = 'sum')
seoul_pivot
# Out:
#            birth_year                                                   \
# city        Dobong-gu Dongdaemun-gu Dongjag-gu Eunpyeong-gu Gangbuk-gu
# date
# 2020-01-01      12960         12960      12960        12960      12960
# 2020-01-02      12960         12960      12960        12960      12960
# 2020-01-03      12960         12960      12960        12960      12960
# 2020-01-04      12960         12960      12960        12960      12960
# 2020-01-05      12960         12960      12960        12960      12960
# ...               ...           ...        ...          ...        ...
# 2020-05-27      12960         12960      12960        12960      12960
# 2020-05-28      12960         12960      12960        12960      12960
# 2020-05-29       9180          9180       9180         9180       9180
# 2020-05-30      12960         12960      12960        12960      12960
# 2020-05-31      12960         12960      12960        12960      12960
#
#                                                                    ...  \
# city       Gangdong-gu Gangnam-gu Gangseo-gu Geumcheon-gu Guro-gu  ...
# date                                                               ...
# 2020-01-01       12960      12960      12960        12960   12960  ...
# 2020-01-02       12960      12960      12960        12960   12960  ...
# 2020-01-03       12960      12960      12960        12960   12960  ...
# 2020-01-04       12960      12960      12960        12960   12960  ...
# 2020-01-05       12960      12960      12960        12960   12960  ...
# ...                ...        ...        ...          ...     ...  ...
# 2020-05-27       12960      12960      12960        12960   12960  ...
# 2020-05-28       12960      12960      12960        12960   12960  ...
# 2020-05-29        9180       9180       9180         9180    9180  ...
# 2020-05-30       12960      12960      12960        12960   12960  ...
# 2020-05-31       12960      12960      12960        12960   12960  ...
#
#               hour                                                           \
# city       Mapo-gu Nowon-gu Seocho-gu Seodaemun-gu Seongbuk-gu Seongdong-gu
# date
# 2020-01-01    3312     3312      3312         3312        3312         3312
# 2020-01-02    3312     3312      3312         3312        3312         3312
# 2020-01-03    3312     3312      3312         3312        3312         3312
# 2020-01-04    3312     3312      3312         3312        3312         3312
# 2020-01-05    3312     3312      3312         3312        3312         3312
# ...            ...      ...       ...          ...         ...          ...
# 2020-05-27    3312     3312      3312         3312        3312         3312
# 2020-05-28    3312     3312      3312         3312        3312         3312
# 2020-05-29    1632     1632      1632         1632        1632         1632
# 2020-05-30    3312     3312      3312         3312        3312         3312
# 2020-05-31    3312     3312      3312         3312        3312         3312
#
#
# city       Songpa-gu Yangcheon-gu Yeongdeungpo-gu Yongsan-gu
# date
# 2020-01-01      3312         3312            3312       3312
# 2020-01-02      3312         3312            3312       3312
# 2020-01-03      3312         3312            3312       3312
# 2020-01-04      3312         3312            3312       3312
# 2020-01-05      3312         3312            3312       3312
# ...              ...          ...             ...        ...
# 2020-05-27      3312         3312            3312       3312
# 2020-05-28      3312         3312            3312       3312
# 2020-05-29      1632         1632            1632       1632
# 2020-05-30      3312         3312            3312       3312
# 2020-05-31      3312         3312            3312       3312
#
# [151 rows x 75 columns]

# %%
# 컬럼의 데이터가 두개가 있음

seoul_pivot.columns
# Out:
# MultiIndex([('birth_year',       'Dobong-gu'),
#             ('birth_year',   'Dongdaemun-gu'),
#             ('birth_year',      'Dongjag-gu'),
#             ('birth_year',    'Eunpyeong-gu'),
#             ('birth_year',      'Gangbuk-gu'),
#             ('birth_year',     'Gangdong-gu'),
#             ('birth_year',      'Gangnam-gu'),
#             ('birth_year',      'Gangseo-gu'),
#             ('birth_year',    'Geumcheon-gu'),
#             ('birth_year',         'Guro-gu'),
#             ('birth_year',       'Gwanak-gu'),
#             ('birth_year',     'Gwangjin-gu'),
#             ('birth_year',       'Jongno-gu'),
#             ('birth_year',         'Jung-gu'),
#             ('birth_year',     'Jungnang-gu'),
#             ('birth_year',         'Mapo-gu'),
#             ('birth_year',        'Nowon-gu'),
#             ('birth_year',       'Seocho-gu'),
#             ('birth_year',    'Seodaemun-gu'),
#             ('birth_year',     'Seongbuk-gu'),
#             ('birth_year',    'Seongdong-gu'),
#             ('birth_year',       'Songpa-gu'),
#             ('birth_year',    'Yangcheon-gu'),
#             ('birth_year', 'Yeongdeungpo-gu'),
#             ('birth_year',      'Yongsan-gu'),
#             (    'fp_num',       'Dobong-gu'),
#             (    'fp_num',   'Dongdaemun-gu'),
#             (    'fp_num',      'Dongjag-gu'),
#             (    'fp_num',    'Eunpyeong-gu'),
#             (    'fp_num',      'Gangbuk-gu'),
#             (    'fp_num',     'Gangdong-gu'),
#             (    'fp_num',      'Gangnam-gu'),
#             (    'fp_num',      'Gangseo-gu'),
#             (    'fp_num',    'Geumcheon-gu'),
#             (    'fp_num',         'Guro-gu'),
#             (    'fp_num',       'Gwanak-gu'),
#             (    'fp_num',     'Gwangjin-gu'),
#             (    'fp_num',       'Jongno-gu'),
#             (    'fp_num',         'Jung-gu'),
#             (    'fp_num',     'Jungnang-gu'),
#             (    'fp_num',         'Mapo-gu'),
#             (    'fp_num',        'Nowon-gu'),
#             (    'fp_num',       'Seocho-gu'),
#             (    'fp_num',    'Seodaemun-gu'),
#             (    'fp_num',     'Seongbuk-gu'),
#             (    'fp_num',    'Seongdong-gu'),
#             (    'fp_num',       'Songpa-gu'),
#             (    'fp_num',    'Yangcheon-gu'),
#             (    'fp_num', 'Yeongdeungpo-gu'),
#             (    'fp_num',      'Yongsan-gu'),
#             (      'hour',       'Dobong-gu'),
#             (      'hour',   'Dongdaemun-gu'),
#             (      'hour',      'Dongjag-gu'),
#             (      'hour',    'Eunpyeong-gu'),
#             (      'hour',      'Gangbuk-gu'),
#             (      'hour',     'Gangdong-gu'),
#             (      'hour',      'Gangnam-gu'),
#             (      'hour',      'Gangseo-gu'),
#             (      'hour',    'Geumcheon-gu'),
#             (      'hour',         'Guro-gu'),
#             (      'hour',       'Gwanak-gu'),
#             (      'hour',     'Gwangjin-gu'),
#             (      'hour',       'Jongno-gu'),
#             (      'hour',         'Jung-gu'),
#             (      'hour',     'Jungnang-gu'),
#             (      'hour',         'Mapo-gu'),
#             (      'hour',        'Nowon-gu'),
#             (      'hour',       'Seocho-gu'),
#             (      'hour',    'Seodaemun-gu'),
#             (      'hour',     'Seongbuk-gu'),
#             (      'hour',    'Seongdong-gu'),
#             (      'hour',       'Songpa-gu'),
#             (      'hour',    'Yangcheon-gu'),
#             (      'hour', 'Yeongdeungpo-gu'),
#             (      'hour',      'Yongsan-gu')],
#            names=[None, 'city'])

# %%
# stack
# 기존 컬럼에 있는 city를 행으로 옮겨줌

seoul_stack = seoul_pivot.stack()
seoul_stack
# Out:
#                             birth_year    fp_num  hour
# date       city
# 2020-01-01 Dobong-gu             12960   6285430  3312
#            Dongdaemun-gu         12960   6918490  3312
#            Dongjag-gu            12960   7669030  3312
#            Eunpyeong-gu          12960   8780930  3312
#            Gangbuk-gu            12960   6160610  3312
# ...                                ...       ...   ...
# 2020-05-31 Seongdong-gu          12960   5662070  3312
#            Songpa-gu             12960  12163070  3312
#            Yangcheon-gu          12960   8138610  3312
#            Yeongdeungpo-gu       12960   8290160  3312
#            Yongsan-gu            12960   4616900  3312
#
# [3775 rows x 3 columns]

# %%
# unstack
# 기존 행에 있는 city를 컬럼으로 옮겨줌

seoul_stack.unstack()
# Out:
#            birth_year                                                   \
# city        Dobong-gu Dongdaemun-gu Dongjag-gu Eunpyeong-gu Gangbuk-gu
# date
# 2020-01-01      12960         12960      12960        12960      12960
# 2020-01-02      12960         12960      12960        12960      12960
# 2020-01-03      12960         12960      12960        12960      12960
# 2020-01-04      12960         12960      12960        12960      12960
# 2020-01-05      12960         12960      12960        12960      12960
# ...               ...           ...        ...          ...        ...
# 2020-05-27      12960         12960      12960        12960      12960
# 2020-05-28      12960         12960      12960        12960      12960
# 2020-05-29       9180          9180       9180         9180       9180
# 2020-05-30      12960         12960      12960        12960      12960
# 2020-05-31      12960         12960      12960        12960      12960
#
#                                                                    ...  \
# city       Gangdong-gu Gangnam-gu Gangseo-gu Geumcheon-gu Guro-gu  ...
# date                                                               ...
# 2020-01-01       12960      12960      12960        12960   12960  ...
# 2020-01-02       12960      12960      12960        12960   12960  ...
# 2020-01-03       12960      12960      12960        12960   12960  ...
# 2020-01-04       12960      12960      12960        12960   12960  ...
# 2020-01-05       12960      12960      12960        12960   12960  ...
# ...                ...        ...        ...          ...     ...  ...
# 2020-05-27       12960      12960      12960        12960   12960  ...
# 2020-05-28       12960      12960      12960        12960   12960  ...
# 2020-05-29        9180       9180       9180         9180    9180  ...
# 2020-05-30       12960      12960      12960        12960   12960  ...
# 2020-05-31       12960      12960      12960        12960   12960  ...
#
#               hour                                                           \
# city       Mapo-gu Nowon-gu Seocho-gu Seodaemun-gu Seongbuk-gu Seongdong-gu
# date
# 2020-01-01    3312     3312      3312         3312        3312         3312
# 2020-01-02    3312     3312      3312         3312        3312         3312
# 2020-01-03    3312     3312      3312         3312        3312         3312
# 2020-01-04    3312     3312      3312         3312        3312         3312
# 2020-01-05    3312     3312      3312         3312        3312         3312
# ...            ...      ...       ...          ...         ...          ...
# 2020-05-27    3312     3312      3312         3312        3312         3312
# 2020-05-28    3312     3312      3312         3312        3312         3312
# 2020-05-29    1632     1632      1632         1632        1632         1632
# 2020-05-30    3312     3312      3312         3312        3312         3312
# 2020-05-31    3312     3312      3312         3312        3312         3312
#
#
# city       Songpa-gu Yangcheon-gu Yeongdeungpo-gu Yongsan-gu
# date
# 2020-01-01      3312         3312            3312       3312
# 2020-01-02      3312         3312            3312       3312
# 2020-01-03      3312         3312            3312       3312
# 2020-01-04      3312         3312            3312       3312
# 2020-01-05      3312         3312            3312       3312
# ...              ...          ...             ...        ...
# 2020-05-27      3312         3312            3312       3312
# 2020-05-28      3312         3312            3312       3312
# 2020-05-29      1632         1632            1632       1632
# 2020-05-30      3312         3312            3312       3312
# 2020-05-31      3312         3312            3312       3312
#
# [151 rows x 75 columns]

# %% [markdown]
# # 과제

# %% [markdown]
# ## 1. SeoulFloating 데이터를 불러들이고 마포구의 유동인구의 평균을 날짜별로 조회

# %%
# 아래와 같은 결과가 나오면 됩니다!!
# 컬럼명은 상관없어요
a = seoulfloating.copy()
a= a[a['city'] == 'Mapo-gu'].groupby('date').agg('mean')['fp_num']
a = pd.DataFrame(a)
a
# Out:
#                   fp_num
# date
# 2020-01-01  26684.409722
# 2020-01-02  29040.173611
# 2020-01-03  29555.381944
# 2020-01-04  28637.916667
# 2020-01-05  27489.027778
# ...                  ...
# 2020-05-27  28822.361111
# 2020-05-28  28824.097222
# 2020-05-29  28533.137255
# 2020-05-30  27227.777778
# 2020-05-31  26583.819444
#
# [151 rows x 1 columns]

# %% [markdown]
# ## 2. patientInfo 데이터를 불러들이고 서울지역 환자수를 날짜별로 조회
#
# - 날짜는 confirmed_date 컬럼을 이용하시면 됩니다

# %%
b = patientInfo.copy()
b = b[b['province'] == 'Seoul'].groupby('confirmed_date').agg('count')['patient_id']
b= pd.DataFrame(b)
b
# Out:
#                 patient_id
# confirmed_date
# 2020-01-23               1
# 2020-01-30               3
# 2020-01-31               3
# 2020-02-02               1
# 2020-02-05               2
# ...                    ...
# 2020-06-25              17
# 2020-06-26              17
# 2020-06-27              14
# 2020-06-28               7
# 2020-06-29               7
#
# [129 rows x 1 columns]

# %% [markdown]
# ## 3.  1번과 2번의 결과물을 날짜를 기준으로 join을 하고 확진자 수가 있는 날짜만 조회

# %%
pd.merge(a, b, right_index = True,  left_index = True, how = 'inner')
# Out:
#                   fp_num  patient_id
# 2020-01-23  27756.631944           1
# 2020-01-30  29385.833333           3
# 2020-01-31  28919.375000           3
# 2020-02-02  26879.618056           1
# 2020-02-05  28737.881944           2
# ...                  ...         ...
# 2020-05-27  28822.361111          25
# 2020-05-28  28824.097222          19
# 2020-05-29  28533.137255           9
# 2020-05-30  27227.777778           6
# 2020-05-31  26583.819444           1
#
# [99 rows x 2 columns]
